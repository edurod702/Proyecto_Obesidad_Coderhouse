# %% [markdown]
# <font size=4>Contexto
#
# Hace cuarenta años, en el mundo el número de personas con peso bajo era mucho mayor que el de las personas obesas. Esta situación se ha invertido y en la actualidad el número de personas obesas duplica el número de personas con peso bajo. De mantenerse la tendencia, para el año 2030 más de 40% de la población del planeta tendrá sobrepeso y más de la quinta parte será obesa.
# De acuerdo a la Organización Mundial de la Salud (OMS), desde 1980 la obesidad se ha duplicado en todo el mundo, llegando en el año 2014 a más de 1 900 millones de adultos mayores de 18 años con sobrepeso, de los cuales, más de 600 millones con obesidad, lo que implica una prevalencia en adultos mayores de 18 años de 39% de sobrepeso y 13% de obesidad. Con respecto a la población infantil, existen más de 41 millones de niños menores de 5 años con sobrepeso u obesidad a nivel mundial, lo que ha significado un incremento de cerca de 11 millones en los últimos 15 años.
# La obesidad es un grave problema de salud pública porque es importante factor de riesgo para enfermedades no transmisibles, que son las de mayor carga de morbimortalidad en el mundo. Un índice de masa corporal (IMC) elevado se relaciona con problemas metabólicos, como resistencia a la insulina, aumento del colesterol y triglicéridos. El sobrepeso y la obesidad aumentan el riesgo para problemas cardiovasculares, como coronariopatías y accidente cerebrovascular. El riesgo de diabetes mellitus de tipo 2 aumenta proporcionalmente con la elevación del IMC. Igualmente, un IMC elevado también aumenta el riesgo para algunos cánceres y patologías osteoarticulares.
# La siguiente presentación tiene por objeto el dar respuesta a las siguientes preguntas:
#
# 1. Entre las principales causas de muerte ¿hay alguna relacionada con un elevado IMC? De ser así, ¿cómo compara el comportamiento a nivel mundial con aquél en México?
# 2. ¿Se han incrementado en México las causas de muerte relacionadas con los hábitos alimentarios en el tiempo? ¿Cómo comparan estos cambios con relación a lo que se observa mundialmente?
#
# Referencia: Miguel Malo-Serrano, Nancy Castillo M., Daniel Pajita D. La obesidad en el mundo. An. Fac. med. vol.78 no.2 Lima abr./jun. 2017. http://dx.doi.org/10.15381/anales.v78i2.13213

# %% [markdown]
# <font size=4>Audiencia
#
# Se pretende que la información relacionada con las respuestas a las preguntas anteriores sea útil a cualquier persona interesada en las causas y consecuencias de la obesidad.

# %% [markdown]
# <font size=4> Limitaciones
#
# La información se restringue a las bases de datos consultadas.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib as mpl
from matplotlib import pyplot as plt

# %%
data = pd.read_csv('C:/DATA/number-of-deaths-by-risk-factor.csv')
data.head()
# Out:
#         Entity Code  Year  \
# 0  Afghanistan  AFG  1990
# 1  Afghanistan  AFG  1991
# 2  Afghanistan  AFG  1992
# 3  Afghanistan  AFG  1993
# 4  Afghanistan  AFG  1994
#
#    Deaths - Cause: All causes - Risk: Outdoor air pollution - OWID - Sex: Both - Age: All Ages (Number)  \
# 0                                               3169
# 1                                               3222
# 2                                               3395
# 3                                               3623
# 4                                               3788
#
#    Deaths - Cause: All causes - Risk: High systolic blood pressure - Sex: Both - Age: All Ages (Number)  \
# 0                                              25633
# 1                                              25872
# 2                                              26309
# 3                                              26961
# 4                                              27658
#
# ...

# %%
data.dtypes
# Out:
# Entity                                                                                                              object
# Code                                                                                                                object
# Year                                                                                                                 int64
# Deaths - Cause: All causes - Risk: Outdoor air pollution - OWID - Sex: Both - Age: All Ages (Number)                 int64
# Deaths - Cause: All causes - Risk: High systolic blood pressure - Sex: Both - Age: All Ages (Number)                 int64
# Deaths - Cause: All causes - Risk: Diet high in sodium - Sex: Both - Age: All Ages (Number)                          int64
# Deaths - Cause: All causes - Risk: Diet low in whole grains - Sex: Both - Age: All Ages (Number)                     int64
# Deaths - Cause: All causes - Risk: Alcohol use - Sex: Both - Age: All Ages (Number)                                  int64
# ...

# %%
data.columns = ['Entity','Code','Year','Outdoor air pollution','High systolic blood pressure','Diet high in sodium','Diet low in whole grains','Alcohol use','Diet low in fruits','Unsafe water source','Secondhand smoke','Low birth weight','Child wasting','Unsafe sex','Diet low in nuts and seeds','Household air pollution from solid fuels','Diet low in vegetables','Low physical activity','Smoking','High fasting plasma glucose','Air pollution','High body-mass index','Unsafe sanitation','No access to handwashing facility','Drug use','Low bone mineral density','Vitamin A deficiency','Child stunting','Discontinued breastfeeding','Non-exclusive breastfeeding','Iron deficiency']
data
# Out:
#            Entity Code  Year  Outdoor air pollution  \
# 0     Afghanistan  AFG  1990                   3169
# 1     Afghanistan  AFG  1991                   3222
# 2     Afghanistan  AFG  1992                   3395
# 3     Afghanistan  AFG  1993                   3623
# 4     Afghanistan  AFG  1994                   3788
# ...           ...  ...   ...                    ...
# 6835     Zimbabwe  ZWE  2015                   2835
# 6836     Zimbabwe  ZWE  2016                   2781
# 6837     Zimbabwe  ZWE  2017                   2700
# 6838     Zimbabwe  ZWE  2018                   2669
# 6839     Zimbabwe  ZWE  2019                   2680
#
#       High systolic blood pressure  Diet high in sodium  \
# 0                            25633                 1045
# 1                            25872                 1055
# 2                            26309                 1075
# 3                            26961                 1103
# ...

# %%
causes_death_total = data[['Outdoor air pollution',
       'High systolic blood pressure', 'Diet high in sodium',
       'Diet low in whole grains', 'Alcohol use', 'Diet low in fruits',
       'Unsafe water source', 'Secondhand smoke', 'Low birth weight',
       'Child wasting', 'Unsafe sex', 'Diet low in nuts and seeds',
       'Household air pollution from solid fuels', 'Diet low in vegetables',
       'Low physical activity', 'Smoking', 'High fasting plasma glucose',
       'Air pollution', 'High body-mass index', 'Unsafe sanitation',
       'No access to handwashing facility', 'Drug use',
       'Low bone mineral density', 'Vitamin A deficiency', 'Child stunting',
       'Discontinued breastfeeding', 'Non-exclusive breastfeeding',
       'Iron deficiency']].sum()

# %% [markdown]
# <font size=4>
#
# Principales causas de muerte en el mundo (1990-2020)

# %%
causes_death_total.plot.bar(figsize=(15, 7))
plt.ylabel('Count')
plt.title('Causes of death Worldwide 1990-2020')
# Out:
# Text(0.5, 1.0, 'Causes of death Worldwide 1990-2020')

# %%
# Datos para Mexico
Mexico= data.loc[data['Entity'] == 'Mexico']
Mexico
# Out:
#       Entity Code  Year  Outdoor air pollution  High systolic blood pressure  \
# 3630  Mexico  MEX  1990                  23192                         40064
# 3631  Mexico  MEX  1991                  23516                         40949
# 3632  Mexico  MEX  1992                  24180                         42402
# 3633  Mexico  MEX  1993                  24833                         44103
# 3634  Mexico  MEX  1994                  25545                         45656
# 3635  Mexico  MEX  1995                  26372                         47942
# 3636  Mexico  MEX  1996                  26828                         49783
# 3637  Mexico  MEX  1997                  27410                         51856
# 3638  Mexico  MEX  1998                  27683                         54163
# 3639  Mexico  MEX  1999                  27858                         55783
# 3640  Mexico  MEX  2000                  27260                         57202
# ...

# %%
Mexico_causes_death_total = Mexico[['Outdoor air pollution',
       'High systolic blood pressure', 'Diet high in sodium',
       'Diet low in whole grains', 'Alcohol use', 'Diet low in fruits',
       'Unsafe water source', 'Secondhand smoke', 'Low birth weight',
       'Child wasting', 'Unsafe sex', 'Diet low in nuts and seeds',
       'Household air pollution from solid fuels', 'Diet low in vegetables',
       'Low physical activity', 'Smoking', 'High fasting plasma glucose',
       'Air pollution', 'High body-mass index', 'Unsafe sanitation',
       'No access to handwashing facility', 'Drug use',
       'Low bone mineral density', 'Vitamin A deficiency', 'Child stunting',
       'Discontinued breastfeeding', 'Non-exclusive breastfeeding',
       'Iron deficiency']].sum()

# %% [markdown]
# <font size=4>
#
# Principales causas de muerte en México (1990-2020)

# %%
Mexico_causes_death_total.plot.bar(figsize=(15, 7))
plt.ylabel('Count')
plt.title('Causes of death Mexico 1990-2020')
# Out:
# Text(0.5, 1.0, 'Causes of death Mexico 1990-2020')

# %%
# Comparaciones
plt.subplots(2,1)

plt.subplot(211)
causes_death_total.plot.bar(figsize=(15, 7))
plt.ylabel('Count')
plt.title('Causes of death Worldwide 1990-2020')
plt.xticks([])

plt.subplot(212)
Mexico_causes_death_total.plot.bar(figsize=(15, 7))
plt.ylabel('Count')
plt.title('Causes of death Mexico 1990-2020')
# Out:
# Text(0.5, 1.0, 'Causes of death Mexico 1990-2020')

# %% [markdown]
# <font size=4> Insight:
#
# Un valor alto de IMC es una causa de muerte más importante en México (3er lugar) que lo que es a nivel mundial (5o lugar).

# %%
plt.subplots(2,1, figsize=(15,7), constrained_layout = True)

plt.subplot(211)
sns.lineplot(x="Year", y='Diet high in sodium', data=data)
plt.ylabel('Diet high in sodium')
plt.title('Causes of death related with nutrition Worldwide')

plt.subplot(212)
sns.lineplot(x="Year", y='Diet high in sodium', data=Mexico)
plt.ylabel('Diet high in sodium')
plt.title('Causes of death related with nutrition Mexico')
# Out:
# Text(0.5, 1.0, 'Causes of death related with nutrition Mexico')

# %%
plt.subplots(2,1, figsize=(15,7), constrained_layout = True)

plt.subplot(211)
sns.lineplot(x="Year", y='Diet low in whole grains', data=data)
plt.ylabel('Diet low in whole grains')
plt.title('Causes of death related with nutrition Worldwide')

plt.subplot(212)
sns.lineplot(x="Year", y='Diet low in whole grains', data=Mexico)
plt.ylabel('Diet low in whole grains')
plt.title('Causes of death related with nutrition Mexico')
# Out:
# Text(0.5, 1.0, 'Causes of death related with nutrition Mexico')

# %%
plt.subplots(2,1, figsize=(15,7), constrained_layout = True)

plt.subplot(211)
sns.lineplot(x="Year", y='Diet low in fruits', data=data)
plt.ylabel('Diet low in fruits')
plt.title('Causes of death related with nutrition Worldwide')

plt.subplot(212)
sns.lineplot(x="Year", y='Diet low in fruits', data=Mexico)
plt.ylabel('Diet low in fruits')
plt.title('Causes of death related with nutrition Mexico')
# Out:
# Text(0.5, 1.0, 'Causes of death related with nutrition Mexico')

# %%
plt.subplots(2,1, figsize=(15,7), constrained_layout = True)

plt.subplot(211)
sns.lineplot(x="Year", y='Diet low in nuts and seeds', data=data)
plt.ylabel('Diet low in nuts and seeds')
plt.title('Causes of death related with nutrition Worldwide')

plt.subplot(212)
sns.lineplot(x="Year", y='Diet low in nuts and seeds', data=Mexico)
plt.ylabel('Diet low in nuts and seeds')
plt.title('Causes of death related with nutrition Mexico')
# Out:
# Text(0.5, 1.0, 'Causes of death related with nutrition Mexico')

# %%
plt.subplots(2,1, figsize=(15,7), constrained_layout = True)

plt.subplot(211)
sns.lineplot(x="Year", y='Diet low in vegetables', data=data)
plt.ylabel('Diet low in vegetables')
plt.title('Causes of death related with nutrition Worldwide')

plt.subplot(212)
sns.lineplot(x="Year", y='Diet low in vegetables', data=Mexico)
plt.ylabel('Diet low in vegetables')
plt.title('Causes of death related with nutrition Mexico')
# Out:
# Text(0.5, 1.0, 'Causes of death related with nutrition Mexico')

# %%
plt.subplots(2,1, figsize=(15,7), constrained_layout = True)

plt.subplot(211)
sns.lineplot(x="Year", y='High body-mass index', data=data)
plt.ylabel('High body-mass index')
plt.title('Causes of death related with nutrition Worldwide')

plt.subplot(212)
sns.lineplot(x="Year", y='High body-mass index', data=Mexico)
plt.ylabel('High body-mass index')
plt.title('Causes of death related with nutrition Mexico')
# Out:
# Text(0.5, 1.0, 'Causes of death related with nutrition Mexico')

# %%
plt.subplots(2,1, figsize=(15,7), constrained_layout = True)

plt.subplot(211)
sns.lineplot(x="Year", y='Low physical activity', data=data)
plt.ylabel('Low physical activity')
plt.title('Causes of death related with nutrition Worldwide')

plt.subplot(212)
sns.lineplot(x="Year", y='Low physical activity', data=Mexico)
plt.ylabel('Low physical activity')
plt.title('Causes of death related with nutrition Mexico')
# Out:
# Text(0.5, 1.0, 'Causes of death related with nutrition Mexico')

# %% [markdown]
# <font size=4> Insight:
#
# Parece existir una tendencia más fuerte en el aumento de muertes asociadas a causas nutricionales, alto IMC y falta de actividad física en México que lo que es a nivel mundial.

# %%
data2 = pd.read_csv('C:/DATA/share-of-adults-defined-as-obese-overweight.csv')
data2.head()
# Out:
#         Entity Code  Year  \
# 0  Afghanistan  AFG  1975
# 1  Afghanistan  AFG  1976
# 2  Afghanistan  AFG  1977
# 3  Afghanistan  AFG  1978
# 4  Afghanistan  AFG  1979
#
#    Indicator:Prevalence of obesity among adults, BMI &GreaterEqual; 30 (crude estimate) (%) - Sex:Both sexes  \
# 0                                                0.4
# 1                                                0.4
# 2                                                0.5
# 3                                                0.5
# 4                                                0.5
#
#    Indicator:Prevalence of overweight among adults, BMI &GreaterEqual; 25 (age-standardized estimate) (%) - Sex:Both sexes
# 0                                                6.1
# 1                                                6.3
# 2                                                6.5
# 3                                                6.8
# 4                                                7.0

# %%
data2.columns = ['Entity','Code','Year','Obesity','Overweight']
data2
# Out:
#            Entity Code  Year  Obesity  Overweight
# 0     Afghanistan  AFG  1975      0.4         6.1
# 1     Afghanistan  AFG  1976      0.4         6.3
# 2     Afghanistan  AFG  1977      0.5         6.5
# 3     Afghanistan  AFG  1978      0.5         6.8
# 4     Afghanistan  AFG  1979      0.5         7.0
# ...           ...  ...   ...      ...         ...
# 8479     Zimbabwe  ZWE  2012     11.1        36.6
# 8480     Zimbabwe  ZWE  2013     11.3        37.0
# 8481     Zimbabwe  ZWE  2014     11.6        37.3
# 8482     Zimbabwe  ZWE  2015     11.9        37.7
# 8483     Zimbabwe  ZWE  2016     12.3        38.2
#
# [8484 rows x 5 columns]

# %%
data2.groupby('Entity').sum()
# Out:
#                   Year  Obesity  Overweight
# Entity
# Afghanistan      83811     75.4       550.9
# Africa           83811    193.6       860.8
# Albania          83811    504.7      1857.6
# Algeria          83811    582.6      1923.8
# Americas         83811    750.5      2097.9
# ...                ...      ...         ...
# Western Pacific  83811    108.6       828.1
# World            83811    327.4      1232.5
# Yemen            83811    285.1      1386.6
# Zambia           83811    136.6       812.0
# Zimbabwe         83811    304.5      1151.0
#
# [202 rows x 3 columns]

# %%
obesity_overweight = data2[['Obesity','Overweight']].sum()

# %%
obesity_overweight.plot.bar(figsize=(15, 7))
plt.ylabel('Count')
plt.title('Worldwide 1975-2016')
# Out:
# Text(0.5, 1.0, 'Worldwide 1975-2016')

# %%
# Datos para Mexico
Mexico2= data2.loc[data2['Entity'] == 'Mexico']

# %%
obesity_overweight_Mexico = Mexico2[['Obesity','Overweight']].sum()
obesity_overweight_Mexico.plot.bar(figsize=(15, 7))
plt.ylabel('Count')
plt.title('Mexico 1975-2016')
# Out:
# Text(0.5, 1.0, 'Mexico 1975-2016')

# %% [markdown]
# <font size=4> Insight:
#
# El sobrepeso y la obesidad en México siguen los patrones observados a nivel mundial.
